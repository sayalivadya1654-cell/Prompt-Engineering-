# %% [markdown]
# <a href="https://colab.research.google.com/github/sayalivadya1654-cell/Prompt-Engineering-/blob/main/PromptEngineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - GROQ_API_KEY

# %% [markdown]
# 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

# %% [markdown]
# -

# %%
pip install groq

# %%
pip show groq
# Out:
# Name: groq
# Version: 1.5.0
# Summary: The official Python library for the groq API
# Home-page: https://github.com/groq/groq-python
# Author:
# Author-email: Groq <support@groq.com>
# License: Apache-2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: anyio, distro, httpx, pydantic, sniffio, typing-extensions
# Required-by:

# %%
pip install groq langchain-groq python-dotenv

# %%
pip install groq langchain-core langchain-groq python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

groq_api_key = os.getenv("GROQ_API_KEY")

print(groq_api_key)
# Out:
# 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

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv(override=True)

llm = ChatGroq(model="llama-3.3-70b-versatile")

response = llm.invoke("What is Prompt Engineering?")
print(response.content)
# Out:
# Prompt Engineering is a field of research and practice that focuses on designing and optimizing text prompts to elicit specific, accurate, and relevant responses from artificial intelligence (AI) models, particularly large language models (LLMs). The goal of prompt engineering is to craft high-quality prompts that can effectively communicate the desired task, context, and requirements to the AI model, enabling it to generate more accurate, informative, and useful responses.
#
# Prompt engineering involves a range of techniques, including:
#
# 1. **Prompt design**: Creating well-structured and clear prompts that accurately convey the task or question being asked.
# 2. **Prompt tuning**: Refining and adjusting prompts to improve the quality and relevance of the AI model's responses.
# 3. **Prompt optimization**: Using various methods, such as reinforcement learning or gradient-based optimization, to optimize prompts for specific tasks or objectives.
# 4. **Prompt analysis**: Analyzing the performance of different prompts and identifying factors that contribute to their effectiveness.
#
# Effective prompt engineering can significantly improve the performance of AI models in various applications, such as:
#
# 1. **Natural Language Processing (NLP)**: Improving language understanding, text classification, sentiment analysis, and language generation.
# 2. **Question Answering**: Enhancing the accuracy and relevance of answers generated by AI models.
# 3. **Text Summarization**: Generating concise and informative summaries of long documents or texts.
# 4. **Chatbots and Conversational AI**: Creating more engaging, informative, and helpful conversational interfaces.
#
# The key benefits of prompt engineering include:
#
# 1. **Improved accuracy**: Better prompts can lead to more accurate and relevant responses from AI models.
# 2. **Increased efficiency**: Well-designed prompts can reduce the need for extensive training data or manual annotation.
# 3. **Enhanced user experience**: Effective prompts can improve the overall user experience in applications such as chatbots, virtual assistants, and language translation systems.
#
# However, prompt engineering also poses challenges, such as:
#
# 1. **Prompt bias**: The risk of introducing biases or errors into the AI model's responses through poorly designed prompts.
# 2. **Overfitting**: The potential for prompts to become overly specialized to a specific task or dataset, limiting their generalizability.
# 3. **Lack of interpretability**: The difficulty of understanding why a particular prompt is effective or ineffective, making it challenging to improve or generalize prompts.
#
# Overall, prompt engineering is a critical aspect of developing and deploying effective AI models, and its importance is likely to grow as AI technology continues to advance and become more ubiquitous.

# %%
from langchain_groq import ChatGroq

# %%
load_dotenv()
# Out:
# True

# %%
os.getenv("GROQ_API_KEY")
# Out:
# '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'

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

load_dotenv(override=True)

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
response = llm.invoke("What is Prompt Engineering?")
print(response.content)
# Out:
# Prompt Engineering is a field of study and practice that focuses on designing and optimizing the input prompts or queries used to interact with artificial intelligence (AI) systems, particularly language models. The goal of prompt engineering is to craft high-quality prompts that elicit specific, accurate, and relevant responses from AI models.
#
# Prompt engineering involves understanding how language models process and respond to different types of input, and using that knowledge to design prompts that:
#
# 1. **Elicit specific information**: Prompt engineers aim to design prompts that extract specific data or insights from the AI model.
# 2. **Improve response accuracy**: Well-designed prompts can help reduce errors and increase the accuracy of the AI model's responses.
# 3. **Enhance response relevance**: Prompt engineers strive to create prompts that generate responses that are relevant to the task or question at hand.
# 4. **Optimize response fluency**: Prompts can be designed to influence the tone, style, and fluency of the AI model's responses.
#
# To achieve these goals, prompt engineers use various techniques, including:
#
# 1. **Natural Language Processing (NLP)**: Understanding the syntax, semantics, and pragmatics of language to design effective prompts.
# 2. **Linguistic analysis**: Analyzing the language used in prompts to identify patterns, biases, and areas for improvement.
# 3. **Experimentation and testing**: Iteratively testing and refining prompts to optimize their performance.
# 4. **Knowledge graph integration**: Incorporating domain-specific knowledge and ontologies to inform prompt design.
#
# Applications of prompt engineering include:
#
# 1. **Conversational AI**: Designing effective prompts for chatbots, virtual assistants, and other conversational AI systems.
# 2. **Language translation**: Crafting prompts that improve machine translation accuracy and fluency.
# 3. **Text summarization**: Developing prompts that extract relevant information and summarize long documents.
# 4. **Question answering**: Designing prompts that elicit accurate and relevant responses to user queries.
#
# As AI models become increasingly prevalent, the importance of prompt engineering will continue to grow, enabling more effective and efficient human-AI interactions.

# %%
response = llm.invoke("Explain Python in simple words.")
print(response.content)
# Out:
# **What is Python?**
# Python is a high-level programming language that is easy to learn and use. It's like a set of instructions that a computer can understand.
#
# **Key Features:**
#
# 1. **Simple Syntax**: Python's code is easy to read and write, making it a great language for beginners.
# 2. **Versatile**: Python can be used for various tasks, such as:
# 	* Building websites and web applications
# 	* Analyzing data and creating visualizations
# 	* Automating tasks and workflows
# 	* Creating games and interactive programs
# 3. **Large Community**: Python has a vast and active community, which means there are many resources available to help you learn and solve problems.
# 4. **Cross-Platform**: Python can run on multiple operating systems, including Windows, macOS, and Linux.
#
# **Why Use Python?**
# Python is a great language to learn because it:
#
# 1. **Easy to Learn**: Python has a simple syntax and is relatively easy to pick up, even for those with no prior programming experience.
# 2. **Fast Development**: Python's syntax and nature make it ideal for rapid prototyping and development.
# 3. **Wide Range of Applications**: Python can be used in various fields, from web development to data science and more.
#
# Overall, Python is a powerful and versatile language that's perfect for beginners and experienced programmers alike.

# %%
response = llm.invoke("Explain Prompt Engineering with a real-life example.")
print(response.content)
# Out:
# **Introduction to Prompt Engineering**
# =====================================
#
# Prompt engineering is a technique used in natural language processing (NLP) and artificial intelligence (AI) to optimize the input prompts or queries given to a language model or AI system. The goal of prompt engineering is to elicit a specific, accurate, and relevant response from the model.
#
# **Real-Life Example: Product Description Generation**
# ---------------------------------------------------
#
# Suppose we want to use a language model to generate product descriptions for an e-commerce website. We have a product called "SmartWater Bottle" with the following features:
#
# * 1-liter capacity
# * Insulated to keep drinks hot or cold for 12 hours
# * BPA-free and dishwasher safe
# * Tracks water intake and sends reminders to drink more
#
# **Initial Prompt**
# -----------------
#
# Our initial prompt might be: "Write a product description for a smart water bottle."
#
# **Response**
# ------------
#
# The language model generates a response: "This water bottle is great for staying hydrated on-the-go. It's made of durable materials and has a comfortable design."
#
# **Limitations**
# --------------
#
# The response is generic and does not mention the specific features of the SmartWater Bottle. This is because the prompt is too vague, and the model is not provided with enough context to generate a detailed and accurate description.
#
# **Prompt Engineering**
# ---------------------
#
# To improve the response, we can use prompt engineering techniques to refine the prompt. Here are a few strategies:
#
# 1. **Provide more context**: Add specific details about the product, such as its features and benefits.
# 2. **Use specific keywords**: Include relevant keywords, such as "insulated," "BPA-free," and "water intake tracking."
# 3. **Define the tone and style**: Specify the tone and style of the description, such as "friendly and informative."
#
# **Revised Prompt**
# -----------------
#
# Our revised prompt might be: "Write a friendly and informative product description for the SmartWater Bottle, a 1-liter insulated water bottle that tracks water intake and sends reminders to drink more. Mention its BPA-free and dishwasher-safe materials, and highlight its ability to keep drinks hot or cold for 12 hours."
#
# **Response**
# ------------
#
# The language model generates a revised response: "Stay hydrated and on top of your water intake with the SmartWater Bottle! This 1-liter insulated water bottle keeps drinks hot or cold for 12 hours and tracks your water intake, sending reminders to drink more throughout the day. Made from BPA-free and dishwasher-safe materials, this bottle is both durable and easy to clean. Perfect for fitness enthusiasts, busy professionals, and anyone looking to upgrade their hydration game!"
#
# **Conclusion**
# --------------
#
# By using prompt engineering techniques, we were able to elicit a more accurate, detailed, and relevant response from the language model. The revised prompt provided more context, specific keywords, and defined the tone and style of the description, resulting in a high-quality product description that effectively showcases the features and benefits of the SmartWater Bottle.

# %% [markdown]
# # complete setup code #

# %%
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq

load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=groq_api_key
)

response = llm.invoke("What is Prompt Engineering?")

print(response.content)
# Out:
# Prompt Engineering is a field of study and practice that focuses on designing and optimizing text prompts or inputs to elicit specific, accurate, and relevant responses from artificial intelligence (AI) models, particularly large language models (LLMs). The goal of prompt engineering is to craft high-quality prompts that can effectively communicate the desired task, context, or intent to the AI model, allowing it to generate more accurate, informative, and useful outputs.
#
# Prompt engineering involves a range of techniques, including:
#
# 1. **Prompt design**: Crafting clear, concise, and well-defined prompts that accurately convey the desired task or question.
# 2. **Prompt optimization**: Refining and iterating on prompts to improve the quality and relevance of the AI model's responses.
# 3. **Prompt tuning**: Adjusting prompts to adapt to specific AI models, domains, or tasks.
# 4. **Evaluation**: Assessing the effectiveness of prompts in eliciting desired responses from AI models.
#
# Effective prompt engineering can significantly improve the performance of AI models in various applications, such as:
#
# 1. **Natural Language Processing (NLP)**: Improving language understanding, text generation, and language translation.
# 2. **Question Answering**: Enhancing the accuracy and relevance of answers generated by AI models.
# 3. **Text Summarization**: Optimizing the quality and conciseness of summaries generated by AI models.
# 4. **Chatbots and Conversational AI**: Designing engaging and effective conversational interfaces.
#
# To achieve successful prompt engineering, practitioners must consider factors such as:
#
# 1. **Linguistic nuances**: Understanding the subtleties of language and how they impact AI model performance.
# 2. **Domain knowledge**: Familiarity with the specific domain or topic being addressed.
# 3. **AI model capabilities**: Awareness of the strengths and limitations of the AI model being used.
# 4. **Evaluation metrics**: Establishing clear metrics to assess the effectiveness of prompts and AI model responses.
#
# By applying prompt engineering techniques, developers and researchers can unlock the full potential of AI models, leading to more accurate, informative, and engaging interactions between humans and machines.
